# %% [markdown]
# #### imports

# %%
import pandas as pd

# %% [markdown]
# # Visual Crossing Weather united states of America 2021-01-01 to 2023-03-01

# %%
name_of_file = 'Dallas_Texas_2019-01-01_to_2023-07-22'

# %%
df = pd.read_csv(f"../data/{name_of_file}.csv") # reading the csv in pandas

# %%
df.head() # checking the first 5 rows
# Out:
#             name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Dallas, Texas  2019-01-01     43.1     36.5  39.2          38.3
# 1  Dallas, Texas  2019-01-02     36.8     32.8  34.7          31.8
# 2  Dallas, Texas  2019-01-03     40.2     35.4  37.7          37.2
# 3  Dallas, Texas  2019-01-04     59.3     37.2  45.4          59.3
# 4  Dallas, Texas  2019-01-05     70.9     37.3  53.1          70.9
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          28.6       31.8  32.0      75.3  ...          4.8        3
# 1          24.6       27.5  31.5      88.6  ...          0.7        0
# 2          27.6       31.3  35.6      92.2  ...          2.7        2
# 3          29.1       41.9  33.7      66.8  ...         12.6        6
# 4          37.3       52.9  37.1      57.9  ...         13.0        6
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2019-01-01T07:29:43  2019-01-01T17:31:53       0.85
# ...

# %%
df.shape
# Out:
# (1664, 33)

# %%
df['idx'] = df.index # adding an index column as required by AutoML
df.head()
# Out:
#             name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Dallas, Texas  2019-01-01     43.1     36.5  39.2          38.3
# 1  Dallas, Texas  2019-01-02     36.8     32.8  34.7          31.8
# 2  Dallas, Texas  2019-01-03     40.2     35.4  37.7          37.2
# 3  Dallas, Texas  2019-01-04     59.3     37.2  45.4          59.3
# 4  Dallas, Texas  2019-01-05     70.9     37.3  53.1          70.9
#
#    feelslikemin  feelslike   dew  humidity  ...  uvindex  severerisk  \
# 0          28.6       31.8  32.0      75.3  ...        3         NaN
# 1          24.6       27.5  31.5      88.6  ...        0         NaN
# 2          27.6       31.3  35.6      92.2  ...        2         NaN
# 3          29.1       41.9  33.7      66.8  ...        6         NaN
# 4          37.3       52.9  37.1      57.9  ...        6         NaN
#
#                sunrise               sunset  moonphase            conditions  \
# ...

# %%
# writing back to new csv with the idx column (remember to not add index again)
df.to_csv(f"../data/{name_of_file}_w_index.csv", sep=',', header=True,index=False)

# %%
df.reindex(sorted(df.columns), axis=1).head(3)
# Out:
#    cloudcover            conditions    datetime  \
# 0        81.9      Partially cloudy  2019-01-01
# 1        95.0  Snow, Rain, Overcast  2019-01-02
# 2        93.2  Snow, Rain, Overcast  2019-01-03
#
#                                          description   dew  feelslike  \
# 0                  Partly cloudy throughout the day.  32.0       31.8
# 1  Cloudy skies throughout the day with a chance ...  31.5       27.5
# 2  Cloudy skies throughout the day with a chance ...  35.6       31.3
#
#    feelslikemax  feelslikemin  humidity               icon  ...  \
# 0          38.3          28.6      75.3  partly-cloudy-day  ...
# 1          31.8          24.6      88.6               rain  ...
# 2          37.2          27.6      92.2               rain  ...
#
#                sunrise               sunset  temp  tempmax  tempmin  uvindex  \
# 0  2019-01-01T07:29:43  2019-01-01T17:31:53  39.2     43.1     36.5        3
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.severerisk.nunique()
# Out:
# 8

# %%
df.reindex(sorted(df.columns), axis=1).select_dtypes(include="object").columns
# Out:
# Index(['conditions', 'datetime', 'description', 'icon', 'name', 'preciptype',
#        'stations', 'sunrise', 'sunset'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations',
#        'idx'],
#       dtype='object')

# %%
num_rows = df.shape[0]
num_rows
# Out:
# 1664

# %%
train_size = 0.8
val_size = 0.1
test_size = 0.1
train_index = round(train_size*num_rows)
val_index = round((train_size+val_size)*num_rows)
print(train_index,val_index)
# Out:
# 1331 1498

# %%
df_test = df.iloc[val_index:]
df_test.head()
# Out:
#                name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 1498  Dallas, Texas  2023-02-07     63.4     47.6  57.1          63.4
# 1499  Dallas, Texas  2023-02-08     48.5     39.8  45.5          44.6
# 1500  Dallas, Texas  2023-02-09     64.1     34.4  48.2          64.1
# 1501  Dallas, Texas  2023-02-10     50.0     37.5  43.2          45.3
# 1502  Dallas, Texas  2023-02-11     54.7     35.6  43.7          54.7
#
#       feelslikemin  feelslike   dew  humidity  precip  precipprob  \
# 1498          42.5       56.1  53.7      88.7   0.300       100.0
# 1499          37.1       40.6  43.1      91.5   0.653       100.0
# 1500          31.8       47.5  39.5      74.5   0.039       100.0
# 1501          31.6       36.3  32.8      66.8   0.000         0.0
# 1502          27.3       40.1  33.3      68.0   0.000         0.0
#
#       precipcover preciptype  snow  snowdepth  windgust  windspeed  winddir  \
# ...

# %%
df_test[['datetime','idx']].to_csv(f"../data/test_{name_of_file}_w_index.csv", sep=',', header=True,index=False)

# %%
df_test[['datetime','idx']]
# Out:
#         datetime   idx
# 1498  2023-02-07  1498
# 1499  2023-02-08  1499
# 1500  2023-02-09  1500
# 1501  2023-02-10  1501
# 1502  2023-02-11  1502
# ...          ...   ...
# 1659  2023-07-18  1659
# 1660  2023-07-19  1660
# 1661  2023-07-20  1661
# 1662  2023-07-21  1662
# 1663  2023-07-22  1663
#
# [166 rows x 2 columns]

# %%
index = 'idx'
timeseries='datetime'
target='tempmax', 'tempmin'
columns_to_ignore = ['name','temp', 'feelslikemax','feelslikemin', 'feelslike', 
                     'precip', 'precipprob', 'preciptype', 'snow', 'snowdepth', 
                     'severerisk','moonphase', 'conditions', 'description', 'icon', 'stations',
                    ]
columns_to_train = [
    'dew', 'humidity', 'precipcover','windgust','windspeed', 'winddir', 
    'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation', 'solarenergy', 
    'uvindex', 'sunrise','sunset', 
    ]

# %%
df_test = df.iloc[-168:,:]
df_test
# Out:
#                name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 1496  Dallas, Texas  2023-02-05     70.4     41.3  56.0          70.4
# 1497  Dallas, Texas  2023-02-06     71.6     52.7  62.5          71.6
# 1498  Dallas, Texas  2023-02-07     63.4     47.6  57.1          63.4
# 1499  Dallas, Texas  2023-02-08     48.5     39.8  45.5          44.6
# 1500  Dallas, Texas  2023-02-09     64.1     34.4  48.2          64.1
# ...             ...         ...      ...      ...   ...           ...
# 1659  Dallas, Texas  2023-07-18    109.3     87.0  98.9         109.0
# 1660  Dallas, Texas  2023-07-19    108.6     86.1  98.1         110.6
# 1661  Dallas, Texas  2023-07-20    103.4     83.4  93.4         105.3
# 1662  Dallas, Texas  2023-07-21    103.2     83.0  92.8         106.1
# 1663  Dallas, Texas  2023-07-22    104.6     84.3  95.3         105.6
#
#       feelslikemin  feelslike   dew  humidity  ...  uvindex  severerisk  \
# ...

# %%
df_test.to_csv(f"../data/test_{name_of_file}_w_index.csv", sep=',', header=True,index=False)
