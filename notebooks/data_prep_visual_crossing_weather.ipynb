# %% [markdown]
# #### imports

# %%
import pandas as pd

# %% [markdown]
# # Visual Crossing Weather united states of America 2021-01-01 to 2023-03-01

# %%
df = pd.read_csv("../data/united states of America 2021-01-01 to 2023-03-01.csv") # reading the csv in pandas

# %%
df.head() # checking the first 5 rows
# Out:
#                        name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  united states of America  2020-01-01     51.0     36.2  44.2          51.0
# 1  united states of America  2020-01-02     53.0     32.4  42.2          53.0
# 2  united states of America  2020-01-03     53.0     47.0  50.3          53.0
# 3  united states of America  2020-01-04     58.9     46.9  52.8          58.9
# 4  united states of America  2020-01-05     46.0     35.4  40.7          39.4
#
#    feelslikemin  feelslike   dew  humidity  precip  precipprob  precipcover  \
# 0          32.7       40.5  24.5      46.6   0.000           0         0.00
# 1          28.3       40.4  31.1      66.3   0.000           0         0.00
# 2          43.0       48.9  46.8      89.0   0.217         100        50.00
# 3          40.3       51.8  50.5      92.4   0.349         100        41.67
# 4          29.5       33.9  25.5      54.9   0.000           0         0.00
#
# ...

# %%
df.shape
# Out:
# (1277, 33)

# %%
df['idx'] = df.index # adding an index column as required by AutoML
df.head()
# Out:
#                        name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  united states of America  2020-01-01     51.0     36.2  44.2          51.0
# 1  united states of America  2020-01-02     53.0     32.4  42.2          53.0
# 2  united states of America  2020-01-03     53.0     47.0  50.3          53.0
# 3  united states of America  2020-01-04     58.9     46.9  52.8          58.9
# 4  united states of America  2020-01-05     46.0     35.4  40.7          39.4
#
#    feelslikemin  feelslike   dew  humidity  precip  precipprob  precipcover  \
# 0          32.7       40.5  24.5      46.6   0.000           0         0.00
# 1          28.3       40.4  31.1      66.3   0.000           0         0.00
# 2          43.0       48.9  46.8      89.0   0.217         100        50.00
# 3          40.3       51.8  50.5      92.4   0.349         100        41.67
# 4          29.5       33.9  25.5      54.9   0.000           0         0.00
#
# ...

# %%
# writing back to new csv with the idx column (remember to not add index again)
df.to_csv("../data/united states of America 2021-01-01 to 2023-03-01_w_index.csv", sep=',', header=True,index=False)

# %%
df.reindex(sorted(df.columns), axis=1).head(3)
# Out:
#    cloudcover              conditions    datetime  \
# 0        99.9          Rain, Overcast  2021-01-01
# 1        89.8  Rain, Partially cloudy  2021-01-02
# 2        98.4          Rain, Overcast  2021-01-03
#
#                                          description   dew  feelslike  \
# 0         Cloudy skies throughout the day with rain.  30.3       31.8
# 1  Partly cloudy throughout the day with early mo...  39.0       41.9
# 2  Cloudy skies throughout the day with a chance ...  37.1       35.9
#
#    feelslikemax  feelslikemin  humidity  icon  idx  moonphase  \
# 0          34.8          28.7      75.8  rain    0       0.59
# 1          56.9          31.5      81.2  rain    1       0.63
# 2          42.7          31.8      87.7  rain    2       0.66
#
#                        name  precip  precipcover  precipprob preciptype  \
# 0  united states of America   0.810        41.67         100       rain
# 1  united states of America   0.001         4.17         100       rain
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.severerisk.nunique()
# Out:
# 0

# %%
df.reindex(sorted(df.columns), axis=1).select_dtypes(include="object").columns
# Out:
# Index(['conditions', 'datetime', 'description', 'icon', 'name', 'preciptype',
#        'stations', 'sunrise', 'sunset'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'datetime', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'severerisk', 'sunrise',
#        'sunset', 'moonphase', 'conditions', 'description', 'icon', 'stations',
#        'idx'],
#       dtype='object')

# %%
num_rows = df.shape[0]
num_rows
# Out:
# 1277

# %%
train_size = 0.8
val_size = 0.1
test_size = 0.1
train_index = round(train_size*num_rows)
val_index = round((train_size+val_size)*num_rows)
print(train_index,val_index)
# Out:
# 1022 1149

# %%
df_test = df.iloc[val_index:]
df_test.head()

# %%
df_test[['datetime','idx']].to_csv("../data/test_united states of America 2021-01-01 to 2023-03-01_w_index.csv", sep=',', header=True,index=False)

# %%
df_test[['datetime','idx']]
# Out:
#         datetime   idx
# 1149  2023-02-23  1149
# 1150  2023-02-24  1150
# 1151  2023-02-25  1151
# 1152  2023-02-26  1152
# 1153  2023-02-27  1153
# ...          ...   ...
# 1272  2023-06-26  1272
# 1273  2023-06-27  1273
# 1274  2023-06-28  1274
# 1275  2023-06-29  1275
# 1276  2023-06-30  1276
#
# [128 rows x 2 columns]
